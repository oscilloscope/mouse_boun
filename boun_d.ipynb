# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.special import entr
from sklearn import preprocessing
import matplotlib.pyplot as plt
import math
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from IPython.display import display
#import itertools
#from itables import init_notebook_mode
import random
#init_notebook_mode(all_interactive=True)
# Out:
# /Users/oguzhansalman/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
def generate_features(mouse_raw):
    x = mouse_raw['x'].copy()
    y = mouse_raw['y'].copy()
    horiz_spd = mouse_raw['x'].diff()/mouse_raw['timestamp'].diff()
    vert_spd = mouse_raw['y'].diff()/mouse_raw['timestamp'].diff()
    tang_spd = np.sqrt((horiz_spd**2)+(vert_spd**2))

    horiz_acc = horiz_spd.diff()/mouse_raw['timestamp'].diff()
    vert_acc = vert_spd.diff()/mouse_raw['timestamp'].diff()
    tang_acc = np.sqrt((horiz_acc**2)+(vert_acc**2))
    
    # Calculate the speed and acceleration of the mouse movement
    dx = np.diff(x)
    dy = np.diff(y)
    speed = np.sqrt(dx ** 2 + dy ** 2)
    acceleration = np.diff(speed)
    #acceleration = np.nan_to_num(acceleration)
    # Calculate the jerk of the mouse movement
    jerk = np.diff(acceleration)
    #jerk = np.mean(jerk)
    


    return { 'horiz_spd': horiz_spd, 'vert_spd': vert_spd, 'tang_spd':tang_spd, 
            'horiz_acc': horiz_acc, 'vert_acc': vert_acc,  
            'tang_acc': tang_acc, 'mouse_rawx_diff': mouse_raw['x'].diff(), 'mouse_rawx_timestamp': mouse_raw['timestamp'].diff(),
           'jerk': jerk }

def ranges(x):
    #print(x.max() - x.min())
    return x.max() - x.min()
def rmssd(x):
    return np.sqrt(np.mean(np.diff(x) ** 2))
def sdsd(x):
    return st.stdev(np.diff(x))
def nni_50(x):
    return  sum(np.abs(np.diff(x)) > 50)

def pnni_50(x):
    return 100 * nni_50(x) / len(x)

def nni_20(x):
    return sum(np.abs(np.diff(x)) > 20)

def pnni_20(x):
    return  100 * nni_20(x) / len(x)

def nni_5(x):
    return sum(np.abs(np.diff(x)) > 5)

def avg_hr(x):
    return  st.mean(100/x)

def avg_hr(x):
    return  st.mean(60000/x)
def std_hr(x):
    return  st.stdev(60000/x)
def min_hr(x):
    return  min(60000/x)
def max_hr(x):
    return  max(60000/x)

def energy(x):
    return sum(np.square(x))
def abs_sum_diff(x):
    return sum(np.abs(np.diff(x)))

# %%
#os.chdir('../')

# %%
os.listdir()

# %%
os.chdir('./datasets')
arr = os.listdir()
files_dict = {}


for i in arr:
    #print(i)
    print(i)
    if i == ".DS_Store":
        continue
    os.chdir(i)

    arr2 = os.listdir()
    print(len(arr2))
    #print(arr2)
    #print(len(arr2))
    #print(i)
    if len(arr2) != 0:#'./training' in arr2: len(arr2) != 0:
        #w = '/content/drive/MyDrive/boun dataset/'+ str(i) + '/training'
        print(arr2)
        w = './training'
        os.chdir(w)
        arr3 = os.listdir()
        files_dict[i] = arr3
        #print(w)
        #print(arr3)
        #print("----")
        os.chdir('../')

    os.chdir('../')
    print(os.listdir())


os.chdir('../')
# Out:
# .DS_Store
# 18
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 9
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 11
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 7
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 16
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 6
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 17
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 1
# 2
# ['.DS_Store', 'training']
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 10
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 19
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 8
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 4
# 1
# ['training']
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 15
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 3
# 1
# ['training']
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 12
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 2
# 2
# ['.DS_Store', 'training']
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 13
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 5
# 1
# ['training']
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']
# 14
# 0
# ['.DS_Store', '18', '9', '11', '7', '16', '6', '17', '1', '10', '19', '8', '4', '15', '3', '12', '2', '13', '5', '14']

# %%
os.listdir()
# Out:
# ['11_mouse.bin',
#  '3_mouse.bin',
#  '.DS_Store',
#  '17_mouse.bin',
#  '8_mouse.bin',
#  '5_mouse.bin',
#  'Untitled.ipynb',
#  '10_mouse.bin',
#  '2_mouse.bin',
#  'datasets',
#  '16_mouse.bin',
#  '9_mouse.bin',
#  'experimenting.ipynb',
#  '4_mouse.bin',
#  '13_mouse.bin',
#  '.gitignore',
#  '1_mouse.bin',
#  '15_mouse.bin',
#  '7_mouse.bin',
#  '18_mouse.bin',
#  '12_mouse.bin',
#  '.ipynb_checkpoints',
#  'boun_d.ipynb',
#  'testing.csv',
#  '.git',
#  '14_mouse.bin',
#  '6_mouse.bin',
#  'BetterCode_7_March.ipynb',
#  '19_mouse.bin',
#  'Getting_help_from_chatgpt.ipynb']

# %%
user_dict = {}
user_dict_by_category = {}
all_category = ['office\n', 'file system\n', 'browsing\n', 'gaming\n', 'entertainment\n', 'development\n']
for i in list(files_dict.keys()):
    user_dict[i] = []
    user_dict_by_category[i] = {}
    for category in all_category:
        user_dict_by_category[i][category] = []
    
    #count = 1
    for j in list(files_dict[i]):

        #user_dict[i][count] = None
        w = './datasets/' + i + '/training/' + j
        file1 = open(w, 'r')
        Lines = file1.readlines()
        txt_array = []
        for k in range(0, len(Lines)):
            #print(Lines[k].split(","))
            txt_array.append(Lines[k].split(","))

        tmpp = pd.DataFrame(txt_array[1:], columns=txt_array[0])
        tmpp['timestamp'] = [int(i[0])*1000 + int(str(i[1])[:3].ljust(3, '0')) for i in tmpp['client_timestamp'].str.split('.')]
        uniquess = tmpp['window\n'].unique().tolist()
#        print(uniquess)
        tmpp = tmpp[tmpp['window\n'] == 'browsing\n']
        user_dict[i].append(tmpp)
        for k in all_category:
            tmpp = tmpp[tmpp['window\n'] == k]
            #tmpp = tmpp[tmpp['state'] == "Move"]
            if tmpp.empty:
                user_dict_by_category[i][k].append(tmpp)

# %%
movement = {}

for i in list(user_dict.keys()):#[2:3]:#[:2]:
    movement[i] = []
    #for j in range(0, 5):
    for j in range(0, len(user_dict[i])):
        tt = user_dict[i][j]
        #print(tt)
        df = pd.DataFrame(tt, columns=tmpp.columns)
        #df = df[df["button"] == "MOVE"]
        #df['timestamp_mili'] = [int(i[0])*1000 + int(i[1]) for i in df['client_timestamp'].str.split('.')]
        movement[i].append(df)

# %%
movement = {}

for i in list(user_dict_by_category[].keys()):#[2:3]:#[:2]:
    movement[i] = []
    #for j in range(0, 5):
    for j in range(0, len(user_dict[i])):
        tt = user_dict[i][j]
        #print(tt)
        df = pd.DataFrame(tt, columns=tmpp.columns)
        #df = df[df["button"] == "MOVE"]
        #df['timestamp_mili'] = [int(i[0])*1000 + int(i[1]) for i in df['client_timestamp'].str.split('.')]
        movement[i].append(df)

# %%
for i in list(movement.keys())[1:2]:
    for k in range(0, 1):
        df2 = pd.DataFrame(movement[i][k], columns=tmpp.columns)
df2.loc[25559:25560]

# %%
import random
click_features = {}
problematic = {}
for i in list(movement.keys()):
    click_features[i] = []
    problematic[i] = []
    #print(i)
    print("User: ",i)
    for k in range(0, len(movement[i])):#[3:4]:#[5:6]:
        #print("session index: ", k)
    #for k in range(0, 1):

    #for k in range(0, 1):#[3:4]:#[5:6]:
  
        df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
        df.to_csv("testing.csv")
        tt = pd.read_csv("testing.csv")
        
#        tt.reset_index(drop=False, inplace=True)

        zz1 = tt[((tt["state"] == "Pressed")| (tt["state"] == "Released")) & (tt['button'] == "Left")]
        zz1_p = zz1[zz1["state"] == "Pressed"]
        zz1_r = zz1[zz1["state"] == "Released"]
        
        tt.set_index("Unnamed: 0", inplace=True)
        
        pressed_indexes = zz1_p['Unnamed: 0']
        released_indexes = zz1_r['Unnamed: 0']

        list1 = list(pressed_indexes)
        list2 = list(released_indexes)
        
        list1_consecutive = []
        list2_consecutive = []
        
        # iterate over all possible pairs of indexes and exclude any pairs that are too close together

        for u in range(min(len(list1), len(list2))):
            if list2[u] == list1[u] + 1:
                list1_consecutive.append(list1[u])
                list2_consecutive.append(list2[u])
        
        #print(list1_consecutive)
        #print(list2_consecutive)
        if len(list1_consecutive) != len(list2_consecutive):
            print("Error")
        
#        print(len(list1_consecutive))
        
        for kk in range(0, len(list1_consecutive)):
            res = tt.loc[list2_consecutive[kk]]['timestamp'] - tt.loc[list1_consecutive[kk]]['timestamp']
            if (res > 0) and (res < 1000):
                click_features[i].append(res)
            else:
                print("The value is ")
                print(res)
                print("list1_consecutive[kk]")
                print(list1_consecutive[kk])
                print("tt.iloc[list1_consecutive[kk]]['timestamp']")
                print(tt.loc[list1_consecutive[kk]]['timestamp'])
                problematic[i].append(list1_consecutive[kk])
                print("Problematic value", str(res))

   # print(click_features[i])
  #  print("This is the length of clicks for user", i)
 #   print(len(click_features[i]))
#    print("-------")
#print(problematic)

zz1.set_index("Unnamed: 0", inplace=True)
#zz1.loc[25559:(25559+1000)]
#tt.loc[25559]
#1573627385696 - 1573627385559
# Out:
# User:  1
# The value is
# 1158
# list1_consecutive[kk]
# 117863
# tt.iloc[list1_consecutive[kk]]['timestamp']
# 1569608391985
# Problematic value 1158
# User:  4
# User:  3
# User:  2
# User:  5
# The value is
# 2245
# list1_consecutive[kk]
# 149884
# tt.iloc[list1_consecutive[kk]]['timestamp']
# 1569577616798
# Problematic value 2245
# The value is
# 7770
# list1_consecutive[kk]
# 195986
# tt.iloc[list1_consecutive[kk]]['timestamp']
# 1569580017369
# Problematic value 7770
# The value is
# 1065
# list1_consecutive[kk]
# 197360
# tt.iloc[list1_consecutive[kk]]['timestamp']
# 1569580062157
# Problematic value 1065

# %%
import random
click_features = {}
problematic = {}
for i in list(movement.keys()):
    click_features[i] = []
    problematic[i] = []
    #print(i)
    print("User: ",i)
    for k in range(0, len(movement[i])):#[3:4]:#[5:6]:
        #print("session index: ", k)
    #for k in range(0, 1):

    #for k in range(0, 1):#[3:4]:#[5:6]:
  
        df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
        df.to_csv("testing.csv")
        tt = pd.read_csv("testing.csv")
        
#        tt.reset_index(drop=False, inplace=True)

        zz1 = tt[((tt["state"] == "Pressed")| (tt["state"] == "Released")) & (tt['button'] == "Right")]
        zz1_p = zz1[zz1["state"] == "Pressed"]
        zz1_r = zz1[zz1["state"] == "Released"]
        
        tt.set_index("Unnamed: 0", inplace=True)
        
        pressed_indexes = zz1_p['Unnamed: 0']
        released_indexes = zz1_r['Unnamed: 0']

        list1 = list(pressed_indexes)
        list2 = list(released_indexes)
        
        list1_consecutive = []
        list2_consecutive = []
        
        # iterate over all possible pairs of indexes and exclude any pairs that are too close together

        for u in range(min(len(list1), len(list2))):
            if list2[u] == list1[u] + 1:
                list1_consecutive.append(list1[u])
                list2_consecutive.append(list2[u])
        
        #print(list1_consecutive)
        #print(list2_consecutive)
        if len(list1_consecutive) != len(list2_consecutive):
            print("Error")
        
        print(len(list1_consecutive))
        
        for kk in range(0, len(list1_consecutive)):
            res = tt.loc[list2_consecutive[kk]]['timestamp'] - tt.loc[list1_consecutive[kk]]['timestamp']
            if (res > 0) and (res < 1000):
                click_features[i].append(res)
            else:
                print("The value is ")
                print(res)
                print("list1_consecutive[kk]")
                print(list1_consecutive[kk])
                print("tt.iloc[list1_consecutive[kk]]['timestamp']")
                print(tt.loc[list1_consecutive[kk]]['timestamp'])
                problematic[i].append(list1_consecutive[kk])
                print("Problematic value", str(res))

    print(click_features[i])
print(problematic)

zz1.set_index("Unnamed: 0", inplace=True)
#zz1.loc[25559:(25559+1000)]
#tt.loc[25559]
#1573627385696 - 1573627385559

# %%
df[df['button'] == "Right"]

# %%
df.loc[40415:40430]

# %%
click_features

# %%
zz1[zz1['button'] == "Right"]

# %%
# zz = user_dict['1'][0]
# zz1 = zz[(zz["state"] == "Pressed")| (zz["state"] == "Released")]
# zz1_p = zz1[zz1["state"] == "Pressed"]
# zz1_r = zz1[zz1["state"] == "Released"]
# pressed_indexes = zz1_p.index
# released_indexes = zz1_r.index

# list1 = list(pressed_indexes)
# list2 = list(released_indexes)
# # print(released_indexes)
# # print(pressed_indexes)

# threshold = 3

# # create empty lists to store the filtered indexes
# filtered_pressed_indexes = []
# filtered_released_indexes = []
# list1_consecutive = []
# list2_consecutive = []
# # iterate over all possible pairs of indexes and exclude any pairs that are too close together

# for i in range(min(len(list1), len(list2))):
#     if list2[i] == list1[i] + 1:
#         list1_consecutive.append(list1[i])
#         list2_consecutive.append(list2[i])

        
# print(list1_consecutive)
# print(list2_consecutive)
# list1_consecutive[0]
# zz.iloc[list2_consecutive[0]]['timestamp'] - zz.iloc[list1_consecutive[0]]['timestamp']
# #@zz1_p[list2_consecutive[0]] - zz1_r[list1_consecutive[0]]
# # pressed_indexes = np.array(zz22_p_index)
# # released_indexes = np.array(zz22_r_index)

# # # set a threshold for the minimum distance between indexes
# # threshold = 1

# # # find the absolute differences between the indexes
# # diffs = np.abs(pressed_indexes[:, np.newaxis] - released_indexes)

# # # find the valid pairs of indexes
# # valid_pairs = np.argwhere(diffs > threshold)

# # # extract the filtered indexes of Pressed and Released states
# # filtered_pressed_indexes = pressed_indexes[valid_pairs[:, 0]]
# # filtered_released_indexes = released_indexes[valid_pairs[:, 1]]

# # # print the filtered indexes of Pressed and Released states
# # print("Filtered Pressed:", filtered_pressed_indexes)
# # print("Filtered Released:", filtered_released_indexes)

# %%
# import random
# click_features = {}
# for i in list(movement.keys()):#[:1]:
#     click_features[i] = []
#     #print(i)

#     for k in range(0, len(movement[i])):#[3:4]:#[5:6]:

#     #for k in range(0, 1):#[3:4]:#[5:6]:
  
#         df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
#         df.to_csv("testing.csv")
#         tt = pd.read_csv("testing.csv")
#         move_data_down = tt[tt["state"] == "Pressed"]
#         move_data_up = tt[tt["state"] == "Released"]
#         print("===")
#         #print((len(move_data_down)))
#         #print((len(move_data_up)))
#         tt = pd.DataFrame()
#         print("-----")
#         #if (len(move_data_down)) == (len(move_data_up)):
#         for z in range(0, len(move_data_down)):
#             #print(move_data_up['timestamp'].iloc[z] - move_data_down['timestamp'].iloc[z])
#             #print(int(move_data_up['client_timestamp'].str.split('.')[0]) - int((move_data_down['timestamp'].str.split('.')[0])))
#             #print(move_data_up['timestamp'] - move_data_down['timestamp'])
#             tt['Released'] = move_data_up['timestamp']
#             tt['Pressed'] = move_data_down['timestamp']
#             #click_features[i].append(move_data_up['timestamp'].iloc[z] - move_data_down['timestamp'].iloc[z])
#                 #print(random.choice(click_features[i]))

# %%
aa = pd.concat([move_data_up['timestamp'], move_data_down['timestamp']])
aa

# %%
print(tt.index)
print(move_data_up.index)
print(move_data_down.index)

# %%
[move_data_up['timestamp']]

# %%
# #tmpp[tmpp['window\n']== 'browsing\n']
# tmpp[tmpp['state'] != "Move"]

# %%
experimenting = user_dict['1'][0]

# %%
# experimenting['rounded_timestamp'] = np.where(experimenting['timestamp'] < 1000, 0, np.floor(experimenting['timestamp'] / 1000) * 1000)
# experimenting

# %% [markdown]
# ## In the cell below, I tried to calculate the total timestamp passed for each list of the dataframes

# %%
def calculate_acceleration_and_direction(points, threshold=1.0):
    # Convert points to numpy array and separate into x, y, and time arrays
#    points = np.array(points)
    x = points["x"]
    y = points["y"]
    times = points["timestamp"]

    # Calculate time differences in seconds
    time_diffs = np.diff(times) / 1000.0

    # Calculate distance between points
    dists = np.sqrt(np.diff(x)**2 + np.diff(y)**2)

    # Calculate speed between points in pixels per second
    speeds = dists / time_diffs

    # Find the index where the speed is close to zero
    idx = np.argmin(speeds)

    # Calculate acceleration just before the speed reaches zero
    if speeds[idx] < threshold:
        accel = (speeds[idx] - speeds[idx-5]) / time_diffs[idx-5]
    else:
        accel = None

    # Calculate movement direction between points
    dx = np.diff(x)
    dy = np.diff(y)
    directions = np.arctan2(dy, dx)
    
    
    
    degrees = np.degrees(directions)

    # Create a figure with axes
    fig, ax = plt.subplots()

    # Plot the points as a scatter plot
    ax.scatter(x, y, color='red')

    # Plot the directions as arrows
    ax.quiver(x[:-1], y[:-1], dx, dy, degrees, cmap='viridis', scale=10)

    # Add labels and title
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('Direction of line segments')

    # Show the plot
    plt.show()
    

    # Replace NaNs in direction with the mean direction
#    mean_direction = np.mean(directions[~np.isnan(directions)])
#    directions[np.isnan(directions)] = mean_direction

    return accel, speeds, directions




final_data_test = pd.DataFrame()
total_array = []

features_array = []
test = []
total_0 = 0
diff = 0
for i in list(movement.keys())[:1]:

    print(i)
    total_times = []

    for k in range(0, len(movement[i]))[1:2]:#[5:6]:

    #for k in range(0, 1):#[3:4]:#[5:6]:

        df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
        df.to_csv("testing.csv")
        tt = pd.read_csv("testing.csv")

        tt = tt[tt["state"] == "Move"]







        proper_a = []
        a = [d for _, d in tt.groupby(tt.index - np.arange(len(tt)))]
        #print(len(a))
        # for u in a:
        #     #print(len(u))
        #     proper_a.append(u)
        
        #print(proper_a)
        for u in a:
            first_timestamp = u['timestamp'].min()
            last_timestamp = u['timestamp'].max()
            time_passed = (last_timestamp - first_timestamp)/1000
            if time_passed > 1 and time_passed < 2:
#                print()
                total_times.append(u)
#        print(total_times)
        for times in total_times:
            times['curr_user'] = i
            acc, speeds, dic = calculate_acceleration_and_direction(times)
            
            
            # Convert directions to degrees for easier interpretation
    
            
            
            
            
            
            # plt.plot(dic)
            # plt.show()
            # plt.clf()
  #          times["acceleration"] = acc
 #           times["direction"] = dic
#            final_data_test = pd.concat([final_data_test, times])
#        final_data_test
    
#final_data_test

# %%
def calculate_dwell_times(data, bin_size):
    # Create list of bin x and y coordinates
    bin_x = [i for i in range(0, 500, bin_size)]
    bin_y = [i for i in range(0, 500, bin_size)]

    # Function to calculate bin number of a point
    def calculate_bin(point, bin_list):
        return math.floor(point/bin_size)

    # Create new columns for bin numbers
    data['bin_x'] = data['x'].apply(calculate_bin, bin_list=bin_x)
    data['bin_y'] = data['y'].apply(calculate_bin, bin_list=bin_y)

    # Create new columns for bin coordinates
    data['bin_x_coord'] = data['bin_x'] * bin_size
    data['bin_y_coord'] = data['bin_y'] * bin_size

    # Create new column for dwell time
    data['dwell_time'] = 0

    # Loop through each row of dataframe
    for index, row in data.iterrows():
        # Skip first row
        if index == 0:
            continue

        # Get previous row
        prev_row = data.iloc[index-1]

        # Check if current row is in same bin as previous row
        if (row['bin_x'], row['bin_y']) == (prev_row['bin_x'], prev_row['bin_y']):
            # Calculate dwell time as difference between timestamps
            dwell_time = row['timestamp'] - prev_row['timestamp']
            data.at[index, 'dwell_time'] = dwell_time

    # Create new dataframe to store results
    results_df = pd.DataFrame(columns=['bin_x', 'bin_y', 'dwell_time'])

    # Loop through each unique bin_x, bin_y pair in original dataframe
    for bin_x, bin_y in data[['bin_x', 'bin_y']].drop_duplicates().values:
        # Filter dataframe to rows with current bin_x, bin_y pair
        bin_df = data[(data['bin_x'] == bin_x) & (data['bin_y'] == bin_y)]

        # If there's only one row, skip it
        if len(bin_df) == 1:
            continue

        # Sum the dwell time for all rows in current bin_x, bin_y pair
        total_dwell_time = bin_df['dwell_time'].sum()

        # Add current bin_x, bin_y pair and total dwell time to results dataframe
        results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)

    return results_df

# %%
total_array = []

features_array = []
test = []
total_0 = 0
diff = 0
for i in list(movement.keys()):#[:1]:

    #print(i)

    for k in range(0, len(movement[i])):#[3:4]:#[5:6]:

    #for k in range(0, 1):#[3:4]:#[5:6]:

        df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
        df.to_csv("testing.csv")
        tt = pd.read_csv("testing.csv")

        tt = tt[tt["state"] == "Move"]







        proper_a = []
        a = [d for _, d in tt.groupby(tt.index - np.arange(len(tt)))]
        #print(len(a))
        for u in a:
            first_timestamp = u['timestamp'].min()
            last_timestamp = u['timestamp'].max()
            time_passed = (last_timestamp - first_timestamp)/1000
            if time_passed > 3 and time_passed < 10:
                proper_a.append(u)
#            if len(u) > 200:
                #print(len(u))
                #proper_a.append(u)
                
        
        a = proper_a
        #print(len(a))
        for kk in range(0, len(a)):
            features = {}
            features['user'] = i
            #for kk in range(0, 2):

            #if kk == 2:
            #    print(kk)
            xx = pd.DataFrame(a[kk], columns=tmpp.columns)
            xx = xx.drop_duplicates(subset='timestamp', keep='first')
            # xx.to_csv("testing.csv")
            # tt = pd.read_csv("testing.csv")





            xx['x'] = xx['x'].astype(int)
            xx['y'] = xx['y'].astype(int)
            xx['timestamp'] = xx['timestamp'].astype('int64')

            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 200)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_200'] = max_row['bin_x']
            features['bin_y_200'] = max_row['bin_y']
            features['dwell_time_200'] = max_row['dwell_time']





            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 100)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_100'] = max_row['bin_x']
            features['bin_y_100'] = max_row['bin_y']
            features['dwell_time_100'] = max_row['dwell_time']


            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 500)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_500'] = max_row['bin_x']
            features['bin_y_500'] = max_row['bin_y']
            features['dwell_time_500'] = max_row['dwell_time']






            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 50)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_50'] = max_row['bin_x']
            features['bin_y_50'] = max_row['bin_y']
            features['dwell_time_50'] = max_row['dwell_time']



            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 25)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_25'] = max_row['bin_x']
            features['bin_y_25'] = max_row['bin_y']
            features['dwell_time_25'] = max_row['dwell_time']



            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 10)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_10'] = max_row['bin_x']
            features['bin_y_10'] = max_row['bin_y']
            features['dwell_time_10'] = max_row['dwell_time']


            yyyx = xx.copy().reset_index()
            #df = pd.DataFrame(data)
            #print("----")
            #print(yyyx)
            #print("----")
            try:
                results = calculate_dwell_times(yyyx, 2)
            except:
                #print(results)
                #print("You entered here")
                continue
            #print("He")
            df = results

            #print(results)

            # Convert dwell_time to numeric data type
            df['dwell_time'] = pd.to_numeric(df['dwell_time'])

            # Find row with highest dwell time
            #print(df)
            try:
                max_row = df.loc[df['dwell_time'].idxmax()]
            except:
                continue

            features['bin_x_2'] = max_row['bin_x']
            features['bin_y_2'] = max_row['bin_y']
            features['dwell_time_2'] = max_row['dwell_time']






            # Print bin_x, bin_y, and dwell_time of row with highest dwell time
            #print("bin_x: ", max_row['bin_x'])
            #print("bin_y: ", max_row['bin_y'])
            #print("dwell_time: ", max_row['dwell_time'])




            b = tt["timestamp"].diff().copy()
            b = b.fillna(0)
            #print(b)
            ind = np.argpartition(b, -len(b))[-len(b):]  
            ind = list(ind)
            count5 = 0
            #print(len(ind))
            #print(ind)
            for yuy in ind:
                #print(count5)
                if count5 < 5:
                    #print(xx[yuy:(yuy + 5)])
                    if not xx[yuy:(yuy+10)].empty:
                        count5 = count5 + 1
                        feature_most_idle = generate_features(xx[yuy:(yuy + 10)])
                        features['mhoriz_spd'] = np.mean(feature_most_idle['horiz_spd'].fillna(0))
                        features['mvert_spd'] = np.mean(feature_most_idle['vert_spd'].fillna(0))
                        features['mtang_spd'] = np.mean(feature_most_idle['tang_spd'].fillna(0))
                        features['mhoriz_acc'] = np.mean(feature_most_idle['horiz_acc'].fillna(0))
                        features['mvert_acc'] = np.mean(feature_most_idle['vert_acc'].fillna(0))
                        features['mtang_acc'] = np.mean(feature_most_idle['tang_acc'].fillna(0))
                        features['mtang_jerk_1'] = np.mean(np.nan_to_num(feature_most_idle['jerk']))
                        #print(features)
                if count5 == 5:
                    break

            time_difference = xx['timestamp'].diff()
            time_difference = [d for d in time_difference if d < 1000]
            sum_b_100_500 = sum((i > 100 and i < 500) for i in time_difference)
            # sum_g_500 = sum(i >500 for i in time_difference)
            features["stops"] = sum_b_100_500
            #features["greater_than_500"] = sum_g_500
            feature_tmp = generate_features(xx)

            horiz_spd = feature_tmp['horiz_spd'].fillna(0)
            
            vert_spd = feature_tmp['vert_spd'].fillna(0)
            tang_spd = feature_tmp['tang_spd'].fillna(0)
            horiz_acc = feature_tmp['horiz_acc'].fillna(0)
            vert_acc = feature_tmp['vert_acc'].fillna(0)
            tang_acc = feature_tmp['tang_acc'].fillna(0)
            tang_jerk = np.nan_to_num(feature_tmp['jerk'])

            feature_tmp_2 = generate_features(xx.head(20))

            horiz_spd_2 = feature_tmp_2['horiz_spd'].fillna(0)
            vert_spd_2 = feature_tmp_2['vert_spd'].fillna(0)
            tang_spd_2 = feature_tmp_2['tang_spd'].fillna(0)
            horiz_acc_2 = feature_tmp_2['horiz_acc'].fillna(0)
            vert_acc_2 = feature_tmp_2['vert_acc'].fillna(0)
            tang_acc_2 = feature_tmp_2['tang_acc'].fillna(0)
            tang_jerk_2 = np.nan_to_num(feature_tmp_2['jerk'])


            #feature_tmp_2_2 = generate_features(xx[:-10])
            feature_tmp_2_2 = generate_features(xx.tail(20))

            horiz_spd_2_l = feature_tmp_2_2['horiz_spd'].fillna(0)
            vert_spd_2_l = feature_tmp_2_2['vert_spd'].fillna(0)
            tang_spd_2_l = feature_tmp_2_2['tang_spd'].fillna(0)
            horiz_acc_2_l = feature_tmp_2_2['horiz_acc'].fillna(0)
            vert_acc_2_l = feature_tmp_2_2['vert_acc'].fillna(0)
            tang_acc_2_l = feature_tmp_2_2['tang_acc'].fillna(0)
            tang_jerk_3 = np.nan_to_num(feature_tmp_2_2['jerk'])
            
            # print(horiz_spd.max() - horiz_spd.min())
            # print()
            kk = 0
            #print(click_features[i])
            features['click'] = random.choice(click_features[i])
            #print(np.mean(horiz_spd_2_l))
            features["short_horiz_2_l" +  str(kk)] = np.mean(horiz_spd_2_l)
            features["short_vert_spd_2_l" +   str(kk)] = np.mean(vert_spd_2_l)
            features["short_tang_spd_2_l" +   str(kk)] = np.mean(tang_spd_2_l)
            features["short_horiz_acc_2_l" +   str(kk)] = np.mean(horiz_acc_2_l)
            features["short_vert_acc_2_l" +   str(kk)] = np.mean(vert_acc_2_l)
            features["short_tang_acc_2_l" +   str(kk)] = np.mean(tang_acc_2_l)


            features["short_horiz_2" +  str(kk)] = np.mean(horiz_spd_2)
            features["short_vert_spd_2" +   str(kk)] = np.mean(vert_spd_2)
            features["short_tang_spd_2" +   str(kk)] = np.mean(tang_spd_2)
            features["short_horiz_acc_2" +   str(kk)] = np.mean(horiz_acc_2)
            features["short_vert_acc_2" +   str(kk)] = np.mean(vert_acc_2)
            features["short_tang_acc_2" +   str(kk)] = np.mean(tang_acc_2)
            features['energy_horiz_spd_' + str(kk)] = sum(np.square(horiz_spd))

            if sum(np.square(horiz_spd)) == float("inf"):
                #'mouse_rawx_diff': mouse_raw['x'].diff(), 'mouse_rawx_timestamp': mouse_raw['timestamp'].diff()}
                print("horiz_speed")
                print(horiz_spd)
                print("np squre")
                print(np.square(horiz_spd))
                print("sum")
                print(sum(np.square(horiz_spd)))
                print("timestamp diff")
                print(feature_tmp["mouse_rawx_timestamp"])
                print("mouse_rawx_diff")
                print(feature_tmp["mouse_rawx_diff"])
                
                #print(sum(np.square(horiz_spd)))
            features['energy_vert_spd_' + str(kk)] = sum(np.square(vert_spd))
            features['energy_tang_spd_' + str(kk)] = sum(np.square(tang_spd))
            features['energy_horiz_acc_' + str(kk)] = sum(np.square(horiz_acc))
            features['energy_vert_acc_' + str(kk)] = sum(np.square(vert_acc))
            features['energy_tang_acc_' + str(kk)] = sum(np.square(tang_acc))
            
            features['jerk22_np.mean_' + str(kk)] = np.mean(tang_jerk)
            features['jerk22_np.std_' + str(kk)] = np.std(tang_jerk)

            features['jerk33_np.mean_' + str(kk)] = np.mean(tang_jerk_2)
            features['jerk33_np.std_' + str(kk)] = np.std(tang_jerk_2)

            features['jerk44_np.mean_' + str(kk)] = np.mean(tang_jerk_3)
            features['jerk44_np.std_' + str(kk)] = np.std(tang_jerk_3)



            #print(ranges(horiz_spd))
            features['ranges_horiz_spd_' + str(kk)] = ranges(horiz_spd)
            features['ranges_vert_spd_' + str(kk)] = ranges(vert_spd)
            features['ranges_tang_spd_' + str(kk)] = ranges(tang_spd)
            features['ranges_horiz_acc_' + str(kk)] = ranges(horiz_acc)
            features['ranges_vert_acc_' + str(kk)] = ranges(vert_acc)
            features['ranges_tang_acc_' + str(kk)] = ranges(tang_acc)
            # if kk == 8:
            #     features['ranges_tang_spd_' + str(kk)] = ranges(tang_spd)
            #     print(features['ranges_tang_spd_' + str(kk)])
            #     print('ranges_tang_spd_' + str(kk))

            features['rmssd_horiz_spd_' + str(kk)] = rmssd(horiz_spd)
            features['rmssd_vert_spd_' + str(kk)] = rmssd(vert_spd)
            features['rmssd_tang_spd_' + str(kk)] = rmssd(tang_spd)
            features['rmssd_horiz_acc_' + str(kk)] = rmssd(horiz_acc)
            features['rmssd_vert_acc_' + str(kk)] = rmssd(vert_acc)
            features['rmssd_tang_acc_' + str(kk)] = rmssd(tang_acc)
            # # test.append(features)
            # features['sdsd_horiz_spd_' + str(kk)] = sdsd(horiz_spd)
            # features['sdsd_vert_spd_' + str(kk)] = sdsd(vert_spd)
            # features['sdsd_tang_spd_' + str(kk)] = sdsd(tang_spd)
            # features['sdsd_horiz_acc_' + str(kk)] = sdsd(horiz_acc)
            # features['sdsd_vert_acc_' + str(kk)] = sdsd(vert_acc)
            # features['sdsd_tang_acc_' + str(kk)] = sdsd(tang_acc)
            
            features['abs_sum_diff_horiz_spd_' + str(kk)] =   abs_sum_diff(horiz_spd)
            features['abs_sum_diff_vert_spd_' + str(kk)] =   abs_sum_diff(vert_spd)
            features['abs_sum_diff_tang_spd_' + str(kk)] =   abs_sum_diff(tang_spd)
            features['abs_sum_diff_horiz_acc_' + str(kk)] =   abs_sum_diff(horiz_acc)
            features['abs_sum_diff_vert_acc_' + str(kk)] =   abs_sum_diff(vert_acc)
            features['abs_sum_diff_tang_acc_' + str(kk)] =   abs_sum_diff(tang_acc)

            #features['click_' + str(kk)] = random.choice(click_features[i])




        #print(features)
        #print()
            features_array.append(features)

            #     return { 'horiz_spd': horiz_spd, 'vert_spd': vert_spd, 'tang_spd':tang_spd, 
            # 'horiz_acc': horiz_acc, 'vert_acc': vert_acc,  
            # 'tang_acc': tang_acc}


            #plt.scatter(tt['x'].iloc[-1], tt['y'].iloc[-1])
            # plt.scatter(tt['x'], tt['y'])
            # plt.show()
                # for o in range(0, len(tt['x'])):
                #     plt.scatter(tt['x'][:o], tt['y'][:o])
                #     plt.show()
        #x = tt['x']
        #y = tt['y']

        
        #for u in range(0, len(x)):
        # plt.scatter(x, y)
        # plt.show()
df_train = pd.DataFrame(features_array)
df_train.dropna(inplace=True)
train = df_train.copy()
na_sum = train.isna().sum().sum()
which_na = train.isna().any()
which_inf = train.isin([np.inf, -np.inf]).any()

#print(na_sum)
#print(which_na)
#print(which_inf)




donottouch = train.copy()

train = donottouch.copy()

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.special import entr
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
all_acc_mean = []
mouse_result_dataframe_total = pd.DataFrame()
for i in list(donottouch["user"].unique()):
    mouse_result_dataframe = pd.DataFrame()
    train = donottouch.copy()
    
    # train["user"] = train_tmp["user"]
    print("----")
    print(i)
    this_user = train[train["user"] == i]
    
    not_this_user = train[train["user"] != i]
    not_this_user = shuffle(not_this_user, random_state=20)[:len(this_user)]
    # print("This is attackers")
    # print(not_this_user)
    # print("----")
    train = pd.concat([this_user, not_this_user])



    # X_new1 = train.copy()                                        # Create duplicate of data
    # X_new1.replace([np.inf, - np.inf], np.nan, inplace = True)
    # train=X_new1.dropna()



    train.loc[train["user"] != i, "user"] = "Attacker"

    #train = train.dropna()
    # print(train["user"])
    Y =  train.loc[:,'user']
    Y = (Y == "Attacker").astype(int)
    
    # print("This is Y")
    # print(Y)
    X = train.loc[:, train.columns != 'user']


    # highest_non_inf = X.max().loc[lambda v: v<np.Inf].max()
    # X.replace(np.Inf, highest_non_inf)

    # highest_non_inf_n = X.min().loc[lambda v: v>np.Inf].min()
    # X.replace(-np.Inf, highest_non_inf_n)

    scaler = StandardScaler()
    # try:
    X = scaler.fit_transform(X)
    # except:
    #     print(X)
    #which_inf = X.isna().any()
    #print(which_inf)

    X = preprocessing.normalize(X)

    
    x_train,x_val,y_train,y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)
    X_train,X_val,Y_train,Y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)   
    print("len(y_val)")
    print(len(y_val))
    # print("Train Y labels:")  
    # print(Y_train.value_counts())
    # print("+")
    # print("Test Y labels: ")
    # print(Y_val.value_counts())
    # print("this is y_val")
    # print(y_val)

    # xgb_clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
    #         colsample_bynode=1, colsample_bytree=0.8,
    #         enable_categorical=False, gamma=0, gpu_id=0,
    #         importance_type=None, interaction_constraints='',
    #         learning_rate=0.1, max_delta_step=0, max_depth=4, use_label_encoder=False,
    #         min_child_weight=3, missing=np.nan,
    #         n_estimators=250, n_jobs=-1, nthread=4, num_class=21,
    #         num_parallel_tree=1, objective='multi:softmax',
    #         random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
    #         seed=27, subsample=0.8, tree_method='exact', verbosity=0, silent=True)
    xgb_clf = XGBClassifier()

    from sklearn.ensemble import RandomForestClassifier
    



    
    # Define the hyperparameter space to search over
    param_distributions = {
        'n_estimators': [10, 50, 100, 200],
        'max_depth': [2, 4, 6, 8],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'subsample': [0.5, 0.7, 0.9],
        'colsample_bytree': [0.5, 0.7, 0.9],
        'gamma': [0, 1, 5],
        'min_child_weight': [1, 5, 10],
    }

    # Create an XGBClassifier
    xgbc = XGBClassifier()

    # Create a randomized search object
  #  model = RandomizedSearchCV(
    #    xgbc, param_distributions, n_iter=50, cv=5, random_state=42)

    # Fit the randomized search object to the data
    #random_search.fit(X, y)

    # Print the best combination of hyperparameters
   # print('Best hyperparameters:', model.best_params_)



    #Create a Gaussian Classifier
    #xgb_clf=RandomForestClassifier()

    # test the model for our validation data and see the accuracy of the model and how many mislabeled classes are there
    model = xgbc.fit(X_train, Y_train)
    model.save_model(i + "_mouse.bin")
    
    Y_pred = model.predict(X_val)
    y_val_classes = np.where(y_val == 1, i, "Attacker")

    mouse_result_dataframe['true_labels'] = y_val_classes
    mouse_result_dataframe['current'] = i
    mouse_result_dataframe['probabilities'] = list(model.predict_proba(x_val)[:, 1])
    mouse_result_dataframe_total = pd.concat([mouse_result_dataframe, mouse_result_dataframe_total])

    # print(Y_pred)
    # print("Number of mislabeled points out of a total %d points : %d" % (X_val.shape[0], (Y_val != Y_pred).sum()))
    # print(Y_pred[(Y_val != Y_pred)])
    # print(Y_val[(Y_val != Y_pred)])
    total_0 = total_0 + X_val.shape[0]
    diff = diff + (Y_val != Y_pred).sum()
    cm = confusion_matrix(y_val,Y_pred)
    print(cm)
    
    Accuracy = accuracy_score(Y_val,Y_pred)
    print(round(Accuracy*100,2))
    all_acc_mean.append(round(Accuracy*100,2))
    print("----")

print("total: ")
print(total_0)
print("diff")
print(diff)
print(np.mean(all_acc_mean))
#total_array.append(np.mean(all_acc_mean))
# Out:
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/258474532.py:304: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   ind = np.argpartition(b, -len(b))[-len(b):]
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# ...
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/258474532.py:304: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   ind = np.argpartition(b, -len(b))[-len(b):]
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/3643675293.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({'bin_x': bin_x, 'bin_y': bin_y, 'dwell_time': total_dwell_time}, ignore_index=True)
# /var/folders/y6/l6247h2n6d18r_d0xrzkn26h0000gn/T/ipykernel_76602/258474532.py:304: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   ind = np.argpartition(b, -len(b))[-len(b):]

# %%
df_train = pd.DataFrame(features_array)
df_train.dropna(inplace=True)
train = df_train.copy()
na_sum = train.isna().sum().sum()
which_na = train.isna().any()
which_inf = train.isin([np.inf, -np.inf]).any()

#print(na_sum)
#print(which_na)
#print(which_inf)




donottouch = train.copy()

train = donottouch.copy()

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.special import entr
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
all_acc_mean = []
mouse_result_dataframe_total = pd.DataFrame()
for i in list(donottouch["user"].unique()):
    mouse_result_dataframe = pd.DataFrame()
    train = donottouch.copy()

    # train["user"] = train_tmp["user"]
    print("----")
    print(i)
    this_user = train[train["user"] == i]

    not_this_user = train[train["user"] != i]
    not_this_user = shuffle(not_this_user, random_state=20)[:len(this_user)]
    # print("This is attackers")
    # print(not_this_user)
    # print("----")
    train = pd.concat([this_user, not_this_user])



    # X_new1 = train.copy()                                        # Create duplicate of data
    # X_new1.replace([np.inf, - np.inf], np.nan, inplace = True)
    # train=X_new1.dropna()



    train.loc[train["user"] != i, "user"] = "Attacker"

    #train = train.dropna()
    # print(train["user"])
    Y =  train.loc[:,'user']
    Y = (Y == "Attacker").astype(int)

    # print("This is Y")
    # print(Y)
    X = train.loc[:, train.columns != 'user']


    # highest_non_inf = X.max().loc[lambda v: v<np.Inf].max()
    # X.replace(np.Inf, highest_non_inf)

    # highest_non_inf_n = X.min().loc[lambda v: v>np.Inf].min()
    # X.replace(-np.Inf, highest_non_inf_n)

    scaler = StandardScaler()
    # try:
    X = scaler.fit_transform(X)
    # except:
    #     print(X)
    #which_inf = X.isna().any()
    #print(which_inf)

    X = preprocessing.normalize(X)


    x_train,x_val,y_train,y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)
    X_train,X_val,Y_train,Y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)
    print("len(y_val)")
    print(len(y_val))
    # print("Train Y labels:")
    # print(Y_train.value_counts())
    # print("+")
    # print("Test Y labels: ")
    # print(Y_val.value_counts())
    # print("this is y_val")
    # print(y_val)

    # xgb_clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
    #         colsample_bynode=1, colsample_bytree=0.8,
    #         enable_categorical=False, gamma=0, gpu_id=0,
    #         importance_type=None, interaction_constraints='',
    #         learning_rate=0.1, max_delta_step=0, max_depth=4, use_label_encoder=False,
    #         min_child_weight=3, missing=np.nan,
    #         n_estimators=250, n_jobs=-1, nthread=4, num_class=21,
    #         num_parallel_tree=1, objective='multi:softmax',
    #         random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
    #         seed=27, subsample=0.8, tree_method='exact', verbosity=0, silent=True)
    xgb_clf = XGBClassifier()

    from sklearn.ensemble import RandomForestClassifier





    # Define the hyperparameter space to search over
    param_distributions = {
        'n_estimators': [10, 50, 100, 200],
        'max_depth': [2, 4, 6, 8],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'subsample': [0.5, 0.7, 0.9],
        'colsample_bytree': [0.5, 0.7, 0.9],
        'gamma': [0, 1, 5],
        'min_child_weight': [1, 5, 10],
    }

    # Create an XGBClassifier
    xgbc = XGBClassifier()

    # Create a randomized search object
    #  model = RandomizedSearchCV(
    #    xgbc, param_distributions, n_iter=50, cv=5, random_state=42)

    # Fit the randomized search object to the data
    #random_search.fit(X, y)

    # Print the best combination of hyperparameters
    # print('Best hyperparameters:', model.best_params_)



    #Create a Gaussian Classifier
    #xgb_clf=RandomForestClassifier()

    # test the model for our validation data and see the accuracy of the model and how many mislabeled classes are there
    model = xgbc.fit(X_train, Y_train)
    model.save_model(i + "_mouse.bin")

    Y_pred = model.predict(X_val)
    y_val_classes = np.where(y_val == 1, i, "Attacker")

    mouse_result_dataframe['true_labels'] = y_val_classes
    mouse_result_dataframe['current'] = i
    mouse_result_dataframe['probabilities'] = list(model.predict_proba(x_val)[:, 1])
    mouse_result_dataframe_total = pd.concat([mouse_result_dataframe, mouse_result_dataframe_total])

    # print(Y_pred)
    # print("Number of mislabeled points out of a total %d points : %d" % (X_val.shape[0], (Y_val != Y_pred).sum()))
    # print(Y_pred[(Y_val != Y_pred)])
    # print(Y_val[(Y_val != Y_pred)])
    total_0 = total_0 + X_val.shape[0]
    diff = diff + (Y_val != Y_pred).sum()
    cm = confusion_matrix(y_val,Y_pred)
    print(cm)

    Accuracy = accuracy_score(Y_val,Y_pred)
    print(round(Accuracy*100,2))
    all_acc_mean.append(round(Accuracy*100,2))
    print("----")

print("total: ")
print(total_0)
print("diff")
print(diff)
print(np.mean(all_acc_mean))
#total_array.append(np.mean(all_acc_mean))

# %%
df_train = pd.DataFrame(features_array)
train = df_train.copy()
na_sum = train.isna().sum().sum()
which_na = train.isna().any()
which_inf = train.isin([np.inf, -np.inf]).any()

#print(na_sum)
#print(which_na)
#print(which_inf)




donottouch = train.copy()

train = donottouch.copy()

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.special import entr
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
all_acc_mean = []
mouse_result_dataframe_total = pd.DataFrame()
for i in list(donottouch["user"].unique()):
    mouse_result_dataframe = pd.DataFrame()
    train = donottouch.copy()
    
    # train["user"] = train_tmp["user"]
    print("----")
    print(i)
    this_user = train[train["user"] == i]
    
    not_this_user = train[train["user"] != i]
    not_this_user = shuffle(not_this_user, random_state=20)[:len(this_user)]
    # print("This is attackers")
    # print(not_this_user)
    # print("----")
    train = pd.concat([this_user, not_this_user])



    # X_new1 = train.copy()                                        # Create duplicate of data
    # X_new1.replace([np.inf, - np.inf], np.nan, inplace = True)
    # train=X_new1.dropna()



    train.loc[train["user"] != i, "user"] = "Attacker"

    #train = train.dropna()
    # print(train["user"])
    Y =  train.loc[:,'user']
    Y = (Y == "Attacker").astype(int)
    
    # print("This is Y")
    # print(Y)
    X = train.loc[:, train.columns != 'user']


    # highest_non_inf = X.max().loc[lambda v: v<np.Inf].max()
    # X.replace(np.Inf, highest_non_inf)

    # highest_non_inf_n = X.min().loc[lambda v: v>np.Inf].min()
    # X.replace(-np.Inf, highest_non_inf_n)

    scaler = StandardScaler()
    print(X)
    # try:
    X = scaler.fit_transform(X)
    # except:
    #     print(X)
    #which_inf = X.isna().any()
    #print(which_inf)

    X = preprocessing.normalize(X)

    
    x_train,x_val,y_train,y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)
    X_train,X_val,Y_train,Y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)   
    print("len(y_val)")
    print(len(y_val))
    # print("Train Y labels:")  
    # print(Y_train.value_counts())
    # print("+")
    # print("Test Y labels: ")
    # print(Y_val.value_counts())
    # print("this is y_val")
    # print(y_val)

    # xgb_clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
    #         colsample_bynode=1, colsample_bytree=0.8,
    #         enable_categorical=False, gamma=0, gpu_id=0,
    #         importance_type=None, interaction_constraints='',
    #         learning_rate=0.1, max_delta_step=0, max_depth=4, use_label_encoder=False,
    #         min_child_weight=3, missing=np.nan,
    #         n_estimators=250, n_jobs=-1, nthread=4, num_class=21,
    #         num_parallel_tree=1, objective='multi:softmax',
    #         random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
    #         seed=27, subsample=0.8, tree_method='exact', verbosity=0, silent=True)
    xgb_clf = XGBClassifier()

    from sklearn.ensemble import RandomForestClassifier
    



    
    # Define the hyperparameter space to search over
    param_distributions = {
        'n_estimators': [10, 50, 100, 200],
        'max_depth': [2, 4, 6, 8],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'subsample': [0.5, 0.7, 0.9],
        'colsample_bytree': [0.5, 0.7, 0.9],
        'gamma': [0, 1, 5],
        'min_child_weight': [1, 5, 10],
    }

    # Create an XGBClassifier
    xgbc = XGBClassifier()

    # Create a randomized search object
  #  model = RandomizedSearchCV(
    #    xgbc, param_distributions, n_iter=50, cv=5, random_state=42)

    # Fit the randomized search object to the data
    #random_search.fit(X, y)

    # Print the best combination of hyperparameters
   # print('Best hyperparameters:', model.best_params_)



    #Create a Gaussian Classifier
    #xgb_clf=RandomForestClassifier()

    # test the model for our validation data and see the accuracy of the model and how many mislabeled classes are there
    model = xgbc.fit(X_train, Y_train)
    model.save_model(i + "_mouse.bin")
    
    Y_pred = model.predict(X_val)
    y_val_classes = np.where(y_val == 1, i, "Attacker")

    mouse_result_dataframe['true_labels'] = y_val_classes
    mouse_result_dataframe['current'] = i
    mouse_result_dataframe['probabilities'] = list(model.predict_proba(x_val)[:, 1])
    mouse_result_dataframe_total = pd.concat([mouse_result_dataframe, mouse_result_dataframe_total])

    # print(Y_pred)
    # print("Number of mislabeled points out of a total %d points : %d" % (X_val.shape[0], (Y_val != Y_pred).sum()))
    # print(Y_pred[(Y_val != Y_pred)])
    # print(Y_val[(Y_val != Y_pred)])
    total_0 = total_0 + X_val.shape[0]
    diff = diff + (Y_val != Y_pred).sum()
    cm = confusion_matrix(y_val,Y_pred)
    print(cm)
    
    Accuracy = accuracy_score(Y_val,Y_pred)
    print(round(Accuracy*100,2))
    all_acc_mean.append(round(Accuracy*100,2))
    print("----")

print("total: ")
print(total_0)
print("diff")
print(diff)
print(np.mean(all_acc_mean))
#total_array.append(np.mean(all_acc_mean))
# Out:
# ----
# 1
#        mhoriz_spd  mvert_spd  mtang_spd  mhoriz_acc  mvert_acc  mtang_acc  \
# 0       -0.045833   0.130462   0.149446   -0.001166   0.007995   0.019284
# 1        1.789420  -1.678733   2.458542    0.027915  -0.024483   0.052750
# 2       -0.144956   0.170833   0.244486   -0.001662   0.003759   0.006399
# 3        0.891071  -0.427619   0.991493   -0.009841   0.008493   0.033186
# 4        0.000000   0.098775   0.098775    0.000000  -0.000472   0.001836
# ...           ...        ...        ...         ...        ...        ...
# 5565    -2.429841   1.684563   2.979414   -0.054673   0.031410   0.106802
# 3691     0.386000  -0.990152   1.069527    0.009667  -0.026882   0.061373
# 11485   -0.391318   0.048342   0.394797   -0.007047  -0.000015   0.012626
# 14407   -1.178052   2.746515   3.003117   -0.059338   0.113372   0.270680
# 10892    0.872817   0.000000   0.872817    0.012745   0.000000   0.023140
#
#                                             mtang_jerk_1  stops  click  \
# 0      [0.0, 1.0, -2.0, 3.0, -1.1715728752538097, -2....      2     93
# 1      [1.859846069963944, 7.96248782865922, -4.98546...      1     11
# 2      [-3.3650114730131495, -2.0807374937048273, -8....      0    179
# 3      [0.4475881183009136, 0.4325462376983751, 0.476...      0     11
# 4                 [3.0, -1.0, 0.0, -1.0, 2.0, -1.0, 0.0]      0    104
# ...                                                  ...    ...    ...
# 5565   [0.04024638437378414, -2.807519099885347, 0.43...      1     94
# 3691   [1.2103584106170109, -0.5309457563395874, -8.3...      2     93
# 11485  [8.20586815591588, -3.1032673122978895, -3.958...      2    132
# 14407  [-3.3986241969031354, -1.3696896155157354, 6.2...      1    143
# 10892             [2.0, -3.0, 7.0, -9.0, 3.0, 5.0, -9.0]      3    125
#
#        short_horiz_2_l0  ...  rmssd_tang_spd_0  rmssd_horiz_acc_0  \
# 0              0.095270  ...          0.322223           0.053885
# 1             -0.064087  ...          0.354913           0.037476
# 2              0.062424  ...          0.153913           0.013498
# 3             -0.084145  ...          0.223064           0.039121
# 4              0.212500  ...          0.155542           0.047919
# ...                 ...  ...               ...                ...
# 5565          -0.063596  ...          0.496214           0.088510
# 3691           0.000000  ...          0.647553           0.034442
# 11485         -0.183275  ...          0.491454           0.079505
# 14407          0.389536  ...          1.107672           0.164501
# 10892          0.110952  ...          0.274861           0.054663
#
#        rmssd_vert_acc_0  rmssd_tang_acc_0  abs_sum_diff_horiz_spd_0  \
# 0              0.064448          0.033169                 14.374905
# 1              0.049990          0.031365                 14.958247
# 2              0.013021          0.007250                  3.250350
# 3              0.030205          0.023816                  5.089881
# 4              0.030751          0.019145                 14.276530
# ...                 ...               ...                       ...
# 5565           0.093049          0.072889                 26.923209
# 3691           0.085688          0.049309                  6.510808
# 11485          0.057474          0.053658                 17.255887
# 14407          0.280703          0.211991                 31.372674
# 10892          0.010965          0.026627                 17.764035
#
#        abs_sum_diff_vert_spd_0  abs_sum_diff_tang_spd_0  \
# 0                    17.108558                21.710143
# 1                    17.400381                22.209171
# 2                     3.493725                 3.635667
# 3                     3.792892                 5.820668
# 4                     8.650797                15.840875
# ...                        ...                      ...
# 5565                 24.494444                33.683212
# 3691                 17.111903                18.129957
# 11485                 5.857399                19.324413
# 14407                41.375963                54.142780
# 10892                 1.392857                18.054427
#
#        abs_sum_diff_horiz_acc_0  abs_sum_diff_vert_acc_0  \
# 0                      3.403693                 4.091336
# 1                      2.753054                 3.301614
# 2                      0.463650                 0.410637
# 3                      1.032831                 0.812453
# 4                      4.259689                 2.296130
# ...                         ...                      ...
# 5565                   6.143395                 6.060921
# 3691                   1.064972                 2.234525
# 11485                  2.665135                 1.312449
# 14407                  7.621690                 9.644322
# 10892                  3.428848                 0.310312
#
#        abs_sum_diff_tang_acc_0
# 0                     2.186455
# 1                     2.139301
# 2                     0.214723
# 3                     0.564314
# 4                     1.708023
# ...                        ...
# 5565                  4.340735
# 3691                  1.229120
# 11485                 1.671884
# 14407                 6.753948
# 10892                 1.761427
#
# [3456 rows x 48 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 31>()
#      74 print(X)
#      75 # try:
# ---> 76 X = scaler.fit_transform(X)
#      77 # except:
#      78 #     print(X)
#      79 #which_inf = X.isna().any()
#      80 #print(which_inf)
#      82 X = preprocessing.normalize(X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:852, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     848 # non-optimized default implementation; override when a better
#     849 # method is possible for a given clustering algorithm
#     850 if y is None:
#     851     # fit method of arity 1 (unsupervised transformation)
# --> 852     return self.fit(X, **fit_params).transform(X)
#     853 else:
#     854     # fit method of arity 2 (supervised transformation)
#     855     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:806, in StandardScaler.fit(self, X, y, sample_weight)
#     804 # Reset internal state before fitting
#     805 self._reset()
# --> 806 return self.partial_fit(X, y, sample_weight)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py:841, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     809 """Online computation of mean and std on X for later scaling.
#     810
#     811 All of X is processed as a single batch. This is intended for cases
#    (...)
#     838     Fitted scaler.
#     839 """
#     840 first_call = not hasattr(self, "n_samples_seen_")
# --> 841 X = self._validate_data(
#     842     X,
#     843     accept_sparse=("csr", "csc"),
#     844     estimator=self,
#     845     dtype=FLOAT_DTYPES,
#     846     force_all_finite="allow-nan",
#     847     reset=first_call,
#     848 )
#     849 n_features = X.shape[1]
#     851 if sample_weight is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:566, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     564     raise ValueError("Validation should be done on X, y or both.")
#     565 elif not no_val_X and no_val_y:
# --> 566     X = check_array(X, **check_params)
#     567     out = X
#     568 elif no_val_X and not no_val_y:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: setting an array element with a sequence.

# %%
total_array = []

features_array = []
test = []
total_0 = 0
diff = 0
for i in list(movement.keys()):#[:1]:

    #print(i)

    for k in range(0, len(movement[i])):#[3:4]:#[5:6]:

    #for k in range(0, 1):#[3:4]:#[5:6]:

        df = pd.DataFrame(movement[i][k], columns=tmpp.columns)
        df.to_csv("testing.csv")
        tt = pd.read_csv("testing.csv")

        tt = tt[tt["state"] == "Move"]







        proper_a = []
        a = [d for _, d in tt.groupby(tt.index - np.arange(len(tt)))]
        #print(len(a))
        for u in a:
            if len(u) > 200:
                #print(len(u))
                proper_a.append(u)
                
        
        a = proper_a
        #print(len(a))
        for kk in range(0, len(a)):
            features = {}
            features['user'] = i
        #for kk in range(0, 2):

            #if kk == 2:
            #    print(kk)
            xx = pd.DataFrame(a[kk], columns=tmpp.columns)
            xx = xx.drop_duplicates(subset='timestamp', keep='first')
            # xx.to_csv("testing.csv")
            # tt = pd.read_csv("testing.csv")





            xx['x'] = xx['x'].astype(int)
            xx['y'] = xx['y'].astype(int)
            xx['timestamp'] = xx['timestamp'].astype(int)


            # b = tt["timestamp"].diff().copy()
            # b = b.fillna(0)
            # #print(b)
            # ind = np.argpartition(b, -len(b))[-len(b):]  
            # ind = list(ind)
            # count5 = 0
            # #print(len(ind))
            # #print(ind)
            # for yuy in ind:
            #     #print(count5)
            #     if count5 < 5:
            #         #print(xx[yuy:(yuy + 5)])
            #         if not xx[yuy:(yuy+10)].empty:
            #             count5 = count5 + 1
            #             feature_most_idle = generate_features(xx[yuy:(yuy + 10)])
            #             features['mhoriz_spd'] = np.mean(feature_most_idle['horiz_spd'].fillna(0))
            #             features['mvert_spd'] = np.mean(feature_most_idle['vert_spd'].fillna(0))
            #             features['mtang_spd'] = np.mean(feature_most_idle['tang_spd'].fillna(0))
            #             features['mhoriz_acc'] = np.mean(feature_most_idle['horiz_acc'].fillna(0))
            #             features['mvert_acc'] = np.mean(feature_most_idle['vert_acc'].fillna(0))
            #             features['mtang_acc'] = np.mean(feature_most_idle['tang_acc'].fillna(0))
            #             #print(features)
            #     if count5 == 5:
            #         break

            time_difference = xx['timestamp'].diff()
            time_difference = [d for d in time_difference if d < 1000]
            sum_b_100_500 = sum((i > 100 and i < 500) for i in time_difference)
            # sum_g_500 = sum(i >500 for i in time_difference)
            features["stops"] = sum_b_100_500
            #features["greater_than_500"] = sum_g_500
            feature_tmp = generate_features(xx)

            horiz_spd = feature_tmp['horiz_spd'].fillna(0)
            
            vert_spd = feature_tmp['vert_spd'].fillna(0)
            tang_spd = feature_tmp['tang_spd'].fillna(0)
            horiz_acc = feature_tmp['horiz_acc'].fillna(0)
            vert_acc = feature_tmp['vert_acc'].fillna(0)
            tang_acc = feature_tmp['tang_acc'].fillna(0)

            feature_tmp_2 = generate_features(xx.head(20))

            horiz_spd_2 = feature_tmp_2['horiz_spd'].fillna(0)
            vert_spd_2 = feature_tmp_2['vert_spd'].fillna(0)
            tang_spd_2 = feature_tmp_2['tang_spd'].fillna(0)
            horiz_acc_2 = feature_tmp_2['horiz_acc'].fillna(0)
            vert_acc_2 = feature_tmp_2['vert_acc'].fillna(0)
            tang_acc_2 = feature_tmp_2['tang_acc'].fillna(0)


            #feature_tmp_2_2 = generate_features(xx[:-10])
            feature_tmp_2_2 = generate_features(xx.tail(20))

            horiz_spd_2_l = feature_tmp_2_2['horiz_spd'].fillna(0)
            vert_spd_2_l = feature_tmp_2_2['vert_spd'].fillna(0)
            tang_spd_2_l = feature_tmp_2_2['tang_spd'].fillna(0)
            horiz_acc_2_l = feature_tmp_2_2['horiz_acc'].fillna(0)
            vert_acc_2_l = feature_tmp_2_2['vert_acc'].fillna(0)
            tang_acc_2_l = feature_tmp_2_2['tang_acc'].fillna(0)
            
            # print(horiz_spd.max() - horiz_spd.min())
            # print()
            kk = 0
            #print(click_features[i])
            features['click'] = random.choice(click_features[i])
            #print(np.mean(horiz_spd_2_l))
#             features["short_horiz_2_l" +  str(kk)] = np.mean(horiz_spd_2_l)
#             features["short_vert_spd_2_l" +   str(kk)] = np.mean(vert_spd_2_l)
#             features["short_tang_spd_2_l" +   str(kk)] = np.mean(tang_spd_2_l)
#             features["short_horiz_acc_2_l" +   str(kk)] = np.mean(horiz_acc_2_l)
#             features["short_vert_acc_2_l" +   str(kk)] = np.mean(vert_acc_2_l)
#             features["short_tang_acc_2_l" +   str(kk)] = np.mean(tang_acc_2_l)


#             features["short_horiz_2" +  str(kk)] = np.mean(horiz_spd_2)
#             features["short_vert_spd_2" +   str(kk)] = np.mean(vert_spd_2)
#             features["short_tang_spd_2" +   str(kk)] = np.mean(tang_spd_2)
#             features["short_horiz_acc_2" +   str(kk)] = np.mean(horiz_acc_2)
#             features["short_vert_acc_2" +   str(kk)] = np.mean(vert_acc_2)
#             features["short_tang_acc_2" +   str(kk)] = np.mean(tang_acc_2)

            features['energy_horiz_spd_' + str(kk)] = sum(np.square(horiz_spd))
            if sum(np.square(horiz_spd)) == float("inf"):
                #'mouse_rawx_diff': mouse_raw['x'].diff(), 'mouse_rawx_timestamp': mouse_raw['timestamp'].diff()}
                print("horiz_speed")
                print(horiz_spd)
                print("np squre")
                print(np.square(horiz_spd))
                print("sum")
                print(sum(np.square(horiz_spd)))
                print("timestamp diff")
                print(feature_tmp["mouse_rawx_timestamp"])
                print("mouse_rawx_diff")
                print(feature_tmp["mouse_rawx_diff"])
                
                #print(sum(np.square(horiz_spd)))
#             features['energy_vert_spd_' + str(kk)] = sum(np.square(vert_spd))
#             features['energy_tang_spd_' + str(kk)] = sum(np.square(tang_spd))
#             features['energy_horiz_acc_' + str(kk)] = sum(np.square(horiz_acc))
#             features['energy_vert_acc_' + str(kk)] = sum(np.square(vert_acc))
#             features['energy_tang_acc_' + str(kk)] = sum(np.square(tang_acc))


#             #print(ranges(horiz_spd))
#             features['ranges_horiz_spd_' + str(kk)] = ranges(horiz_spd)
#             features['ranges_vert_spd_' + str(kk)] = ranges(vert_spd)
#             features['ranges_tang_spd_' + str(kk)] = ranges(tang_spd)
#             features['ranges_horiz_acc_' + str(kk)] = ranges(horiz_acc)
#             features['ranges_vert_acc_' + str(kk)] = ranges(vert_acc)
#             features['ranges_tang_acc_' + str(kk)] = ranges(tang_acc)
#             # if kk == 8:
#             #     features['ranges_tang_spd_' + str(kk)] = ranges(tang_spd)
#             #     print(features['ranges_tang_spd_' + str(kk)])
#             #     print('ranges_tang_spd_' + str(kk))

#             features['rmssd_horiz_spd_' + str(kk)] = rmssd(horiz_spd)
#             features['rmssd_vert_spd_' + str(kk)] = rmssd(vert_spd)
#             features['rmssd_tang_spd_' + str(kk)] = rmssd(tang_spd)
#             features['rmssd_horiz_acc_' + str(kk)] = rmssd(horiz_acc)
#             features['rmssd_vert_acc_' + str(kk)] = rmssd(vert_acc)
#             features['rmssd_tang_acc_' + str(kk)] = rmssd(tang_acc)
#             # # test.append(features)
#             # features['sdsd_horiz_spd_' + str(kk)] = sdsd(horiz_spd)
#             # features['sdsd_vert_spd_' + str(kk)] = sdsd(vert_spd)
#             # features['sdsd_tang_spd_' + str(kk)] = sdsd(tang_spd)
#             # features['sdsd_horiz_acc_' + str(kk)] = sdsd(horiz_acc)
#             # features['sdsd_vert_acc_' + str(kk)] = sdsd(vert_acc)
#             # features['sdsd_tang_acc_' + str(kk)] = sdsd(tang_acc)
            
#             features['abs_sum_diff_horiz_spd_' + str(kk)] =   abs_sum_diff(horiz_spd)
#             features['abs_sum_diff_vert_spd_' + str(kk)] =   abs_sum_diff(vert_spd)
#             features['abs_sum_diff_tang_spd_' + str(kk)] =   abs_sum_diff(tang_spd)
#             features['abs_sum_diff_horiz_acc_' + str(kk)] =   abs_sum_diff(horiz_acc)
#             features['abs_sum_diff_vert_acc_' + str(kk)] =   abs_sum_diff(vert_acc)
#             features['abs_sum_diff_tang_acc_' + str(kk)] =   abs_sum_diff(tang_acc)

            #features['click_' + str(kk)] = random.choice(click_features[i])




        #print(features)
        #print()
            features_array.append(features)

            #     return { 'horiz_spd': horiz_spd, 'vert_spd': vert_spd, 'tang_spd':tang_spd, 
            # 'horiz_acc': horiz_acc, 'vert_acc': vert_acc,  
            # 'tang_acc': tang_acc}


            #plt.scatter(tt['x'].iloc[-1], tt['y'].iloc[-1])
            # plt.scatter(tt['x'], tt['y'])
            # plt.show()
                # for o in range(0, len(tt['x'])):
                #     plt.scatter(tt['x'][:o], tt['y'][:o])
                #     plt.show()
        #x = tt['x']
        #y = tt['y']

        
        #for u in range(0, len(x)):
        # plt.scatter(x, y)
        # plt.show()
df_train = pd.DataFrame(features_array)
train = df_train.copy()
na_sum = train.isna().sum().sum()
which_na = train.isna().any()
which_inf = train.isin([np.inf, -np.inf]).any()

#print(na_sum)
#print(which_na)
#print(which_inf)




donottouch = train.copy()

train = donottouch.copy()

from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import GridSearchCV, StratifiedShuffleSplit
from xgboost.sklearn import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from scipy.special import entr
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
all_acc_mean = []
mouse_result_dataframe_total = pd.DataFrame()
for i in list(donottouch["user"].unique()):
    mouse_result_dataframe = pd.DataFrame()
    train = donottouch.copy()
    
    # train["user"] = train_tmp["user"]
    print("----")
    print(i)
    this_user = train[train["user"] == i]
    
    not_this_user = train[train["user"] != i]
    not_this_user = shuffle(not_this_user, random_state=20)[:len(this_user)]
    # print("This is attackers")
    # print(not_this_user)
    # print("----")
    train = pd.concat([this_user, not_this_user])



    # X_new1 = train.copy()                                        # Create duplicate of data
    # X_new1.replace([np.inf, - np.inf], np.nan, inplace = True)
    # train=X_new1.dropna()



    train.loc[train["user"] != i, "user"] = "Attacker"

    #train = train.dropna()
    # print(train["user"])
    Y =  train.loc[:,'user']
    Y = (Y == "Attacker").astype(int)
    
    # print("This is Y")
    # print(Y)
    X = train.loc[:, train.columns != 'user']


    # highest_non_inf = X.max().loc[lambda v: v<np.Inf].max()
    # X.replace(np.Inf, highest_non_inf)

    # highest_non_inf_n = X.min().loc[lambda v: v>np.Inf].min()
    # X.replace(-np.Inf, highest_non_inf_n)

    scaler = StandardScaler()
    # try:
    X = scaler.fit_transform(X)
    # except:
    #     print(X)
    #which_inf = X.isna().any()
    #print(which_inf)

    X = preprocessing.normalize(X)

    
    x_train,x_val,y_train,y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)
    X_train,X_val,Y_train,Y_val = train_test_split(X,Y, test_size = 0.3, random_state=42, stratify=Y)   
    print("len(y_val)")
    print(len(y_val))
    # print("Train Y labels:")  
    # print(Y_train.value_counts())
    # print("+")
    # print("Test Y labels: ")
    # print(Y_val.value_counts())
    # print("this is y_val")
    # print(y_val)

    # xgb_clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
    #         colsample_bynode=1, colsample_bytree=0.8,
    #         enable_categorical=False, gamma=0, gpu_id=0,
    #         importance_type=None, interaction_constraints='',
    #         learning_rate=0.1, max_delta_step=0, max_depth=4, use_label_encoder=False,
    #         min_child_weight=3, missing=np.nan,
    #         n_estimators=250, n_jobs=-1, nthread=4, num_class=21,
    #         num_parallel_tree=1, objective='multi:softmax',
    #         random_state=27, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
    #         seed=27, subsample=0.8, tree_method='exact', verbosity=0, silent=True)
    xgb_clf = XGBClassifier()

    from sklearn.ensemble import RandomForestClassifier
    



    
    # Define the hyperparameter space to search over
    param_distributions = {
        'n_estimators': [10, 50, 100, 200],
        'max_depth': [2, 4, 6, 8],
        'learning_rate': [0.01, 0.1, 0.2, 0.3],
        'subsample': [0.5, 0.7, 0.9],
        'colsample_bytree': [0.5, 0.7, 0.9],
        'gamma': [0, 1, 5],
        'min_child_weight': [1, 5, 10],
    }

    # Create an XGBClassifier
    xgbc = XGBClassifier()

    # Create a randomized search object
  #  model = RandomizedSearchCV(
    #    xgbc, param_distributions, n_iter=50, cv=5, random_state=42)

    # Fit the randomized search object to the data
    #random_search.fit(X, y)

    # Print the best combination of hyperparameters
   # print('Best hyperparameters:', model.best_params_)



    #Create a Gaussian Classifier
    #xgb_clf=RandomForestClassifier()

    # test the model for our validation data and see the accuracy of the model and how many mislabeled classes are there
    model = xgbc.fit(X_train, Y_train)
    model.save_model(i + "_mouse.bin")
    
    Y_pred = model.predict(X_val)
    y_val_classes = np.where(y_val == 1, i, "Attacker")

    mouse_result_dataframe['true_labels'] = y_val_classes
    mouse_result_dataframe['current'] = i
    mouse_result_dataframe['probabilities'] = list(model.predict_proba(x_val)[:, 1])
    mouse_result_dataframe_total = pd.concat([mouse_result_dataframe, mouse_result_dataframe_total])

    # print(Y_pred)
    # print("Number of mislabeled points out of a total %d points : %d" % (X_val.shape[0], (Y_val != Y_pred).sum()))
    # print(Y_pred[(Y_val != Y_pred)])
    # print(Y_val[(Y_val != Y_pred)])
    total_0 = total_0 + X_val.shape[0]
    diff = diff + (Y_val != Y_pred).sum()
    cm = confusion_matrix(y_val,Y_pred)
    print(cm)
    
    Accuracy = accuracy_score(Y_val,Y_pred)
    print(round(Accuracy*100,2))
    all_acc_mean.append(round(Accuracy*100,2))
    print("----")

print("total: ")
print(total_0)
print("diff")
print(diff)
print(np.mean(all_acc_mean))
#total_array.append(np.mean(all_acc_mean))

# %%
#int(tmpp['client_timestamp'].str.split('.')[i][0])*1000 + int(tmpp['client_timestamp'].str.split('.')[i][1])

# %%
total_array = []
for i in movement:
    for k in movement[i]:
        tt = pd.DataFrame(k, columns=tmpp.columns)
        tt = tt[tt['state'] == 'Move']
        proper_a = []
        a = [d for _, d in tt.groupby(tt.index - np.arange(len(tt)))]
        for u in a:
            if 200 < len(u) < 500:
                proper_a.append(u)
        for xx in proper_a:
            features = {'user': i}
            xx = xx.drop_duplicates(subset='timestamp', keep='first').astype({'x': int, 'y': int, 'timestamp': int})
            b = tt['timestamp'].diff().fillna(0)
            ind = np.argpartition(b, -len(b))[-len(b):]
            for yuy in ind:
                if len(features) >= 7:
                    break
                if 0 < len(xx[yuy:yuy+10]) <= 10:
                    feature_most_idle = generate_features(xx[yuy:yuy+10])
                    features['mhoriz_spd'] = np.mean(feature_most_idle['horiz_spd'].fillna(0))
                    features['mvert_spd'] = np.mean(feature_most_idle['vert_spd'].fillna(0))
                    features['mtang_spd'] = np.mean(feature_most_idle['tang_spd'].fillna(0))
                    features['mhoriz_acc'] = np.mean(feature_most_idle['horiz_acc'].fillna(0))
                    features['mvert_acc'] = np.mean(feature_most_idle['vert_acc'].fillna(0))
                    features['mtang_acc'] = np.mean(feature_most_idle['tang_acc'].fillna(0))
                time_difference = xx['timestamp'].diff()
                time_difference = time_difference[time_difference < 1000]
                features['stops'] = (100 < time_difference) & (time_difference < 500)
            feature_tmp = generate_features(xx)
            feature_tmp_2 = generate_features(xx.head(20))
            feature_tmp_2_2 = generate_features(xx.tail(20))
            for feature_name in ['horiz_spd', 'vert_spd', 'tang_spd', 'horiz_acc', 'vert_acc', 'tang_acc']:
                for feature in [feature_tmp, feature_tmp_2, feature_tmp_2_2]:
                    features[feature_name + '_max'] = feature[feature_name].max()
                    features[feature_name + '_min'] = feature[feature_name].min()
                    features[feature_name + '_mean'] = feature[feature_name].mean()
            total_array.append(features)
